# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
import pandas as pd

df = pd.read_csv("jitennsyadeta.csv")
df.head()
# Out:
#    罪名    手口 管轄警察署（発生地） 管轄交番・駐在所（発生地）  市区町村コード（発生地） 都道府県（発生地） 市区町村（発生地）  \
# 0  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 1  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 2  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 3  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 4  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
#
#   町丁目（発生地） 発生年月日（始期） 発生時（始期）                 発生場所 発生場所の詳細 被害者の年齢 被害者の職業  施錠関係
# 0      青葉町  20240117      23  その他の住宅（３階建て以下共同住宅等）  駐車（輪）場   20歳代    大学生  施錠した
# 1      青葉町  20240227      18               駐車（輪）場  駐車（輪）場   10歳代    中学生  施錠せず
# 2      青葉町  20240528      20               駐車（輪）場  駐車（輪）場   40歳代    その他  施錠した
# 3      青葉町  20240627      21               駐車（輪）場  駐車（輪）場   10歳代    中学生  施錠せず
# 4      青葉町  20240917      14                  その他     その他   20歳代    その他  施錠せず

# %%
df['発生日'] = pd.to_datetime(df['発生年月日（始期）'], format="%Y%m%d", errors='coerce')
df['月'] = df['発生日'].dt.month
df.groupby('月').size()
# Out:
# 月
# 1.0      620
# 2.0      569
# 3.0      681
# 4.0      761
# 5.0      813
# 6.0      826
# 7.0     1027
# 8.0      943
# 9.0      984
# 10.0     956
# 11.0     888
# 12.0     782
# dtype: int64

# %%
df.groupby('発生時（始期）').size().sort_values(ascending=False)
# Out:
# 発生時（始期）
# 7     919
# 18    875
# 17    859
# 16    695
# 8     675
# 19    606
# 12    508
# 20    500
# 15    473
# 10    433
# 21    413
# 9     411
# 13    390
# 14    388
# 11    371
# 6     333
# 22    311
# 23    229
# 0     167
# 不明    115
# 5     113
# 1      74
# 2      32
# 4      30
# 3      23
# dtype: int64

# %%
df.groupby('市区町村（発生地）').size().sort_values(ascending=False)
# Out:
# 市区町村（発生地）
# 船橋市        1263
# 市川市         872
# 柏市          691
# 松戸市         678
# 千葉市中央区      656
# 八千代市        458
# 習志野市        450
# 浦安市         435
# 野田市         367
# 千葉市稲毛区      334
# 千葉市美浜区      328
# 千葉市若葉区      313
# 流山市         302
# 千葉市花見川区     290
# 市原市         285
# 千葉市緑区       213
# 成田市         211
# 四街道市        165
# 木更津市        157
# 佐倉市         146
# 鎌ケ谷市        140
# 印西市         125
# 八街市         115
# 我孫子市        114
# 東金市         103
# 茂原市          94
# 君津市          84
# 旭市           64
# 白井市          63
# 館山市          52
# 富津市          45
# 袖ケ浦市         42
# 富里市          31
# 銚子市          30
# 酒々井町         30
# 大網白里市        26
# 山武市          24
# 香取市          22
# 一宮町          21
# 鴨川市          16
# いすみ市         15
# 栄町           14
# 横芝光町         11
# 匝瑳市           9
# 長生村           9
# 南房総市          8
# 鋸南町           5
# 多古町           4
# 九十九里町         3
# 東庄町           3
# 神崎町           2
# 勝浦市           1
# 御宿町           1
# 睦沢町           1
# 白子町           1
# dtype: int64

# %%
plt.figure(figsize=(12,5))
df["時間帯"].value_counts().plot(kind="bar")
plt.title("時間帯ごとの件数")
plt.xlabel("時間帯")
plt.ylabel("件数")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\asami\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '時間帯'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 2
#       1 plt.figure(figsize=(12,5))
# ----> 2 df["時間帯"].value_counts().plot(kind="bar")
#       3 plt.title("時間帯ごとの件数")
#       4 plt.xlabel("時間帯")
#
# File c:\Users\asami\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\Users\asami\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: '時間帯'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# CSV読み込み
df = pd.read_csv("C:/Users/asami/プログラミング基礎/me/Week6/jitennsyadeta.csv")

# 発生時（始期）を時刻として読み込む
df["発生時"] = pd.to_datetime(df["発生時（始期）"], format="%H:%M", errors="coerce").dt.hour

# 時間帯を分類
def time_zone(h):
    if 0 <= h < 6:
        return "深夜"
    elif 6 <= h < 12:
        return "朝"
    elif 12 <= h < 18:
        return "昼"
    elif 18 <= h <= 23:
        return "夕方"
    else:
        return "不明"

df["時間帯"] = df["発生時"].apply(time_zone)

# グラフ表示
plt.figure(figsize=(12,5))
df["時間帯"].value_counts().plot(kind="bar")
plt.title("時間帯ごとの件数")
plt.show()
# Out:
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 26178 (\N{CJK UNIFIED IDEOGRAPH-6642}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 38291 (\N{CJK UNIFIED IDEOGRAPH-9593}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 24111 (\N{CJK UNIFIED IDEOGRAPH-5E2F}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12372 (\N{HIRAGANA LETTER GO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12392 (\N{HIRAGANA LETTER TO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12398 (\N{HIRAGANA LETTER NO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 20214 (\N{CJK UNIFIED IDEOGRAPH-4EF6}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 19981 (\N{CJK UNIFIED IDEOGRAPH-4E0D}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 26126 (\N{CJK UNIFIED IDEOGRAPH-660E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df.groupby('発生時（始期）').size().sort_values(ascending=False)
# Out:
# 発生時（始期）
# 7     919
# 18    875
# 17    859
# 16    695
# 8     675
# 19    606
# 12    508
# 20    500
# 15    473
# 10    433
# 21    413
# 9     411
# 13    390
# 14    388
# 11    371
# 6     333
# 22    311
# 23    229
# 0     167
# 不明    115
# 5     113
# 1      74
# 2      32
# 4      30
# 3      23
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['罪名', '手口', '管轄警察署（発生地）', '管轄交番・駐在所（発生地）', '市区町村コード（発生地）', '都道府県（発生地）',
#        '市区町村（発生地）', '町丁目（発生地）', '発生年月日（始期）', '発生時（始期）', '発生場所', '発生場所の詳細',
#        '被害者の年齢', '被害者の職業', '施錠関係', '発生時', '時間帯', '日付', '月'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 不明を NaN に変換（カラム名を正しく指定）
df["発生時"] = pd.to_numeric(df["発生時"], errors="coerce")

# 時間帯分類の関数
def time_zone(x):
    if pd.isna(x):
        return "不明"
    elif 0 <= x <= 5:
        return "深夜"
    elif 6 <= x <= 11:
        return "朝"
    elif 12 <= x <= 17:
        return "昼"
    elif 18 <= x <= 23:
        return "夕方"
    else:
        return "不明"

# 時間帯列を追加
df["時間帯"] = df["発生時"].apply(time_zone)

# グラフ作成
plt.figure(figsize=(10,5))
df["時間帯"].value_counts().plot(kind="bar")
plt.title("時間帯ごとの件数")
plt.show()
# Out:
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 26178 (\N{CJK UNIFIED IDEOGRAPH-6642}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 38291 (\N{CJK UNIFIED IDEOGRAPH-9593}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 24111 (\N{CJK UNIFIED IDEOGRAPH-5E2F}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12372 (\N{HIRAGANA LETTER GO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12392 (\N{HIRAGANA LETTER TO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12398 (\N{HIRAGANA LETTER NO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 20214 (\N{CJK UNIFIED IDEOGRAPH-4EF6}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 19981 (\N{CJK UNIFIED IDEOGRAPH-4E0D}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 26126 (\N{CJK UNIFIED IDEOGRAPH-660E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd

file_path = "/mnt/data/jitennsyadeta.csv"

# 最も多いパターン①：shift_jis
try:
    df = pd.read_csv(file_path, encoding="shift_jis")
    print("shift_jis で読み込み成功")
except:
    try:
        # パターン②：cp932（Windows日本語）
        df = pd.read_csv(file_path, encoding="cp932")
        print("cp932 で読み込み成功")
    except:
        try:
            # パターン③：utf-8
            df = pd.read_csv(file_path, encoding="utf-8")
            print("utf-8 で読み込み成功")
        except Exception as e:
            print("どのエンコーディングでも読み込めませんでした:", e)

df.head()
# Out:
# どのエンコーディングでも読み込めませんでした: [Errno 2] No such file or directory: '/mnt/data/jitennsyadeta.csv'
#    罪名    手口 管轄警察署（発生地） 管轄交番・駐在所（発生地）  市区町村コード（発生地） 都道府県（発生地） 市区町村（発生地）  \
# 0  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 1  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 2  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 3  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 4  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
#
#   町丁目（発生地） 発生年月日（始期） 発生時（始期）                 発生場所 発生場所の詳細 被害者の年齢 被害者の職業  施錠関係  \
# 0      青葉町  20240117      23  その他の住宅（３階建て以下共同住宅等）  駐車（輪）場   20歳代    大学生  施錠した
# 1      青葉町  20240227      18               駐車（輪）場  駐車（輪）場   10歳代    中学生  施錠せず
# 2      青葉町  20240528      20               駐車（輪）場  駐車（輪）場   40歳代    その他  施錠した
# 3      青葉町  20240627      21               駐車（輪）場  駐車（輪）場   10歳代    中学生  施錠せず
# 4      青葉町  20240917      14                  その他     その他   20歳代    その他  施錠せず
#
#    発生時 時間帯         日付    月
# 0  NaN  不明 2024-01-17  1.0
# 1  NaN  不明 2024-02-27  2.0
# 2  NaN  不明 2024-05-28  5.0
# 3  NaN  不明 2024-06-27  6.0
# 4  NaN  不明 2024-09-17  9.0

# %%
import pandas as pd

# ★ ここをあなたの PC のファイルの場所に書き換えてください
file_path = r"C:\Users\asami\プログラミング基礎\me\Week6\jitennsyadeta.csv"

# --- エンコーディング自動判定付きの安全ロード ---
encodings = ["utf-8", "shift_jis", "cp932"]

for enc in encodings:
    try:
        print(f"Trying encoding: {enc}")
        df = pd.read_csv(file_path, encoding=enc, on_bad_lines="skip")
        print("Success!")
        break
    except Exception as e:
        print(f"Failed: {enc}")

# 日付を datetime に変換（文字化け対策）
if "日付" in df.columns:
    df["日付"] = pd.to_datetime(df["日付"], errors="coerce")
elif "発生年月日（始期）" in df.columns:
    df["日付"] = pd.to_datetime(df["発生年月日（始期）"], errors="coerce")

df.head()
# Out:
# Trying encoding: utf-8
# Success!
#    罪名    手口 管轄警察署（発生地） 管轄交番・駐在所（発生地）  市区町村コード（発生地） 都道府県（発生地） 市区町村（発生地）  \
# 0  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 1  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 2  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 3  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 4  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
#
#   町丁目（発生地） 発生年月日（始期） 発生時（始期）                 発生場所 発生場所の詳細 被害者の年齢 被害者の職業  施錠関係  \
# 0      青葉町  20240117      23  その他の住宅（３階建て以下共同住宅等）  駐車（輪）場   20歳代    大学生  施錠した
# 1      青葉町  20240227      18               駐車（輪）場  駐車（輪）場   10歳代    中学生  施錠せず
# 2      青葉町  20240528      20               駐車（輪）場  駐車（輪）場   40歳代    その他  施錠した
# 3      青葉町  20240627      21               駐車（輪）場  駐車（輪）場   10歳代    中学生  施錠せず
# 4      青葉町  20240917      14                  その他     その他   20歳代    その他  施錠せず
#
#           日付
# 0 2024-01-17
# 1 2024-02-27
# 2 2024-05-28
# 3 2024-06-27
# 4 2024-09-17

# %%
import pandas as pd

file_path = "/mnt/data/jitennsyadeta.csv"

# ① まず区切り文字を自動判定して読み込む
df = pd.read_csv(file_path, sep=None, engine="python")

# ② 文字コードが怪しい場合はエラー時にリトライ
try:
    df = pd.read_csv(file_path, sep=None, engine="python")
except:
    df = pd.read_csv(file_path, sep=None, engine="python", encoding="shift_jis")
    
print(df.head())
print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[40], line 6
#       3 file_path = "/mnt/data/jitennsyadeta.csv"
#       5 # ① まず区切り文字を自動判定して読み込む
# ----> 6 df = pd.read_csv(file_path, sep=None, engine="python")
#       8 # ② 文字コードが怪しい場合はエラー時にリトライ
#       9 try:
#
# File c:\Users\asami\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\asami\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\asami\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\asami\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\asami\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/data/jitennsyadeta.csv'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# ---------------------------------------------------
# ❶ まず CSV を複数エンコードで読み込む関数
# ---------------------------------------------------
def load_csv_safely(path):
    encodings = ["utf-8-sig", "shift_jis", "cp932", "euc_jp"]
    last_error = None
    for enc in encodings:
        try:
            print(f"Trying encoding: {enc}")
            return pd.read_csv(path, encoding=enc)
        except Exception as e:
            last_error = e
            continue
    raise last_error


# ---------------------------------------------------
# ❷ CSV 読み込み（あなたの CSV ファイル名に変更）
# ---------------------------------------------------
file_path = "jitennsyadeta.csv"   # 例: カレントフォルダに置く
df = load_csv_safely(file_path)

print("読み込み成功!")
print(df.head())

# ---------------------------------------------------
# ❸ 「発生年月日（始期）」 など日付列の名前を自動検出
# ---------------------------------------------------
date_col = None
for col in df.columns:
    if "日" in col or "月" in col or "年" in col:
        date_col = col
        break

if date_col is None:
    raise ValueError("日付らしい列が見つかりません。列名を教えてください。")

print("使用する日付列:", date_col)

# 日付に変換
df["date"] = pd.to_datetime(df[date_col], errors="coerce")
df = df.dropna(subset=["date"])

# ---------------------------------------------------
# ❹ 月ごとの件数カウント
# ---------------------------------------------------
df["month"] = df["date"].dt.month
monthly_counts = df["month"].value_counts().sort_index()

print(monthly_counts)

# ---------------------------------------------------
# ❺ グラフ描画（棒グラフ）
# ---------------------------------------------------
plt.figure(figsize=(10,5))
plt.bar(monthly_counts.index, monthly_counts.values)
plt.xticks(range(1,13))
plt.xlabel("月")
plt.ylabel("事故件数")
plt.title("月ごとの事故件数")
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()
# Out:
# Trying encoding: utf-8-sig
# 読み込み成功!
#    罪名    手口 管轄警察署（発生地） 管轄交番・駐在所（発生地）  市区町村コード（発生地） 都道府県（発生地） 市区町村（発生地）  \
# 0  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 1  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 2  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 3  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 4  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
#
#   町丁目（発生地） 発生年月日（始期） 発生時（始期）                 発生場所 発生場所の詳細 被害者の年齢 被害者の職業  施錠関係
# 0      青葉町  20240117      23  その他の住宅（３階建て以下共同住宅等）  駐車（輪）場   20歳代    大学生  施錠した
# 1      青葉町  20240227      18               駐車（輪）場  駐車（輪）場   10歳代    中学生  施錠せず
# 2      青葉町  20240528      20               駐車（輪）場  駐車（輪）場   40歳代    その他  施錠した
# 3      青葉町  20240627      21               駐車（輪）場  駐車（輪）場   10歳代    中学生  施錠せず
# 4      青葉町  20240917      14                  その他     その他   20歳代    その他  施錠せず
# 使用する日付列: 発生年月日（始期）
# month
# 1      620
# 2      569
# 3      681
# 4      761
# 5      813
# 6      826
# 7     1027
# 8      943
# 9      984
# 10     956
# 11     888
# 12     782
# Name: count, dtype: int64
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 20107 (\N{CJK UNIFIED IDEOGRAPH-4E8B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 25925 (\N{CJK UNIFIED IDEOGRAPH-6545}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 20214 (\N{CJK UNIFIED IDEOGRAPH-4EF6}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 26376 (\N{CJK UNIFIED IDEOGRAPH-6708}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12372 (\N{HIRAGANA LETTER GO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12392 (\N{HIRAGANA LETTER TO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12398 (\N{HIRAGANA LETTER NO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd

file_path = "jitennsyadeta.csv"   # ← あなたのCSV名に変更
df = pd.read_csv(file_path, encoding="cp932")
print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[3], line 4
#       1 import pandas as pd
#       3 file_path = "jitennsyadeta.csv"   # ← あなたのCSV名に変更
# ----> 4 df = pd.read_csv(file_path, encoding="cp932")
#       5 print(df.columns)
#
# File c:\Users\asami\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\asami\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\asami\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\asami\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File c:\Users\asami\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File pandas/_libs/parsers.pyx:574, in pandas._libs.parsers.TextReader.__cinit__()
#
# File pandas/_libs/parsers.pyx:663, in pandas._libs.parsers.TextReader._get_header()
#
# File pandas/_libs/parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2053, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'cp932' codec can't decode byte 0xef in position 0: illegal multibyte sequence

# %%
import pandas as pd
import matplotlib.pyplot as plt

# ====== CSV 読み込み（文字化け対策つき）======
file_path = "jitennsyadeta.csv"  # ←あなたのCSV名に合わせる

# 文字コード自動判定 → ダメなら SJIS・CP932
try:
    df = pd.read_csv(file_path, encoding=None)
except:
    try:
        df = pd.read_csv(file_path, encoding="shift_jis", errors="ignore")
    except:
        df = pd.read_csv(file_path, encoding="cp932", errors="ignore")

# ====== 日付列の読み取り（列名をあなたの CSV に合わせる）======
df["日付"] = pd.to_datetime(df["発生年月日（始期）」"], errors="coerce")

# 月の抽出
df["月"] = df["日付"].dt.month

# ====== 月 → 季節の分類 ======
def to_season(month):
    if month in [12, 1, 2]:
        return "冬"
    elif month in [3, 4, 5]:
        return "春"
    elif month in [6, 7, 8]:
        return "夏"
    else:
        return "秋"

df["季節"] = df["月"].apply(to_season)

# ====== 集計 ======
season_month_count = df.groupby(["季節", "月"]).size().reset_index(name="件数")

# ===== グラフ描画 =====
plt.figure(figsize=(10,6))
plt.bar(season_month_count["月"], season_month_count["件数"])

# ★縦軸・横軸ラベル（あなたのリクエスト部分）★
plt.xlabel("月（1〜12）")     # 横軸
plt.ylabel("事故件数")        # 縦軸

# タイトル
plt.title("季節・月ごとの事故件数")

plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\asami\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '発生年月日（始期）」'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 17
#      14         df = pd.read_csv(file_path, encoding="cp932", errors="ignore")
#      16 # ====== 日付列の読み取り（列名をあなたの CSV に合わせる）======
# ---> 17 df["日付"] = pd.to_datetime(df["発生年月日（始期）」"], errors="coerce")
#      19 # 月の抽出
#      20 df["月"] = df["日付"].dt.month
#
# File c:\Users\asami\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\Users\asami\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: '発生年月日（始期）」'

# %%
import pandas as pd
file_path = "jitennsyadeta.csv"

df = pd.read_csv(file_path, encoding="utf-8")
print(df.head())
# Out:
#    罪名    手口 管轄警察署（発生地） 管轄交番・駐在所（発生地）  市区町村コード（発生地） 都道府県（発生地） 市区町村（発生地）  \
# 0  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 1  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 2  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 3  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 4  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
#
#   町丁目（発生地） 発生年月日（始期） 発生時（始期）                 発生場所 発生場所の詳細 被害者の年齢 被害者の職業  施錠関係
# 0      青葉町  20240117      23  その他の住宅（３階建て以下共同住宅等）  駐車（輪）場   20歳代    大学生  施錠した
# 1      青葉町  20240227      18               駐車（輪）場  駐車（輪）場   10歳代    中学生  施錠せず
# 2      青葉町  20240528      20               駐車（輪）場  駐車（輪）場   40歳代    その他  施錠した
# 3      青葉町  20240627      21               駐車（輪）場  駐車（輪）場   10歳代    中学生  施錠せず
# 4      青葉町  20240917      14                  その他     その他   20歳代    その他  施錠せず

# %%
df = pd.read_csv(file_path, encoding="utf-8-sig")

# %%
df = pd.read_csv(file_path, encoding="cp932")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pd.read_csv(file_path, encoding="cp932")
#
# File c:\Users\asami\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\asami\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\asami\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\asami\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File c:\Users\asami\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File pandas/_libs/parsers.pyx:574, in pandas._libs.parsers.TextReader.__cinit__()
#
# File pandas/_libs/parsers.pyx:663, in pandas._libs.parsers.TextReader._get_header()
#
# File pandas/_libs/parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2053, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'cp932' codec can't decode byte 0xef in position 0: illegal multibyte sequence

# %%
import chardet

file_path = r"C:\Users\asami\jitennsyadeta.csv"  # ←ファイルの実パスに変更

# まず先頭部分を読んで文字コード判別
with open(file_path, 'rb') as f:
    result = chardet.detect(f.read(50000))

print(result)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import chardet
#       3 file_path = r"C:\Users\asami\jitennsyadeta.csv"  # ←ファイルの実パスに変更
#       5 # まず先頭部分を読んで文字コード判別
#
# ModuleNotFoundError: No module named 'chardet'

# %%
plt.savefig("monthly_accidents.png", dpi=300, bbox_inches="tight")

# %%
your-repo/
 ├─ index.html
 ├─ monthly_accidents.png  ← これを追加
 └─ その他のファイル
# Out:
#   Cell In[9], line 2
#     ├─ index.html
#     ^
# SyntaxError: invalid character '├' (U+251C)

# %%
plt.savefig("graph.png")

# %%
/index.html
/graph.png
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 index.html()
#       2 graph.png()
#
# NameError: name 'index' is not defined

# %%
plt.savefig("graph.png")

# %%
<!DOCTYPE html>
<html>
<head>
    <meta charset="utf-8">
    <title>事故グラフ</title>
</head>
<body>
    <h1>月ごとの事故件数</h1>
    <img src="graph.png" alt="graph">
</body>
</html>
# Out:
#   Cell In[15], line 1
#     <!DOCTYPE html>
#     ^
# SyntaxError: invalid syntax

# %%
plt.savefig("graph.png")
plt.show()

# %%
<!DOCTYPE html>
<html>
<head>
    <meta charset="utf-8">
    <title>月ごとの事故件数グラフ</title>
</head>
<body>
    <h1>月ごとの事故件数</h1>
    <img src="graph.png" alt="graph">
</body>
</html>
# Out:
#   Cell In[17], line 1
#     <!DOCTYPE html>
#     ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import matplotlib.pyplot as plt

# ---------------------------------------------------
# ❶ エンコード自動判定して CSV 読み込む関数
# ---------------------------------------------------
def load_csv_safely(path):
    encodings = ["utf-8-sig", "shift_jis", "cp932", "euc_jp"]
    last_error = None
    for enc in encodings:
        try:
            print(f"Trying encoding: {enc}")
            return pd.read_csv(path, encoding=enc)
        except Exception as e:
            last_error = e
            continue
    raise last_error

# ---------------------------------------------------
# ❷ CSV 読み込み（あなたのファイル名に合わせて変更）
# ---------------------------------------------------
file_path = "jitennsyadeta.csv"
df = load_csv_safely(file_path)

print("✔ 読み込み成功!")
print(df.head())

# ---------------------------------------------------
# ❸ 日付列を自動判定
# ---------------------------------------------------
date_col = None
for col in df.columns:
    if "日" in col or "月" in col or "年" in col:
        date_col = col
        break

if date_col is None:
    raise ValueError("日付らしい列が見つかりません。列名を教えてください。")

print("✔ 使用する日付列:", date_col)

# 日付形式に変換
df["date"] = pd.to_datetime(df[date_col], errors="coerce")
df = df.dropna(subset=["date"])

# ---------------------------------------------------
# ❹ 月ごとの件数集計
# ---------------------------------------------------
df["month"] = df["date"].dt.month
monthly_counts = df["month"].value_counts().sort_index()

print("✔ 月ごとの件数")
print(monthly_counts)

# ---------------------------------------------------
# ❺ グラフ描画
# ---------------------------------------------------
plt.figure(figsize=(10,5))
plt.bar(monthly_counts.index, monthly_counts.values)
plt.xticks(range(1,13))
plt.xlabel("月")
plt.ylabel("事故件数")
plt.title("月ごとの事故件数")
plt.grid(True, linestyle="--", alpha=0.5)

# 保存（GitHub Pages で使うため）
plt.savefig("graph.png", dpi=150)

plt.show()

print("✔ graph.png として保存しました！")
# Out:
# Trying encoding: utf-8-sig
# ✔ 読み込み成功!
#    罪名    手口 管轄警察署（発生地） 管轄交番・駐在所（発生地）  市区町村コード（発生地） 都道府県（発生地） 市区町村（発生地）  \
# 0  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 1  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 2  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 3  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
# 4  窃盗  自転車盗       千葉中央         千葉寺駅前      121011.0       千葉県    千葉市中央区
#
#   町丁目（発生地） 発生年月日（始期） 発生時（始期）                 発生場所 発生場所の詳細 被害者の年齢 被害者の職業  施錠関係
# 0      青葉町  20240117      23  その他の住宅（３階建て以下共同住宅等）  駐車（輪）場   20歳代    大学生  施錠した
# 1      青葉町  20240227      18               駐車（輪）場  駐車（輪）場   10歳代    中学生  施錠せず
# 2      青葉町  20240528      20               駐車（輪）場  駐車（輪）場   40歳代    その他  施錠した
# 3      青葉町  20240627      21               駐車（輪）場  駐車（輪）場   10歳代    中学生  施錠せず
# 4      青葉町  20240917      14                  その他     その他   20歳代    その他  施錠せず
# ✔ 使用する日付列: 発生年月日（始期）
# ✔ 月ごとの件数
# month
# 1      620
# 2      569
# 3      681
# 4      761
# 5      813
# 6      826
# 7     1027
# 8      943
# 9      984
# 10     956
# 11     888
# 12     782
# Name: count, dtype: int64
# C:\Users\asami\AppData\Local\Temp\ipykernel_8320\299724962.py:67: UserWarning: Glyph 20107 (\N{CJK UNIFIED IDEOGRAPH-4E8B}) missing from font(s) DejaVu Sans.
#   plt.savefig("graph.png", dpi=150)
# C:\Users\asami\AppData\Local\Temp\ipykernel_8320\299724962.py:67: UserWarning: Glyph 25925 (\N{CJK UNIFIED IDEOGRAPH-6545}) missing from font(s) DejaVu Sans.
#   plt.savefig("graph.png", dpi=150)
# C:\Users\asami\AppData\Local\Temp\ipykernel_8320\299724962.py:67: UserWarning: Glyph 20214 (\N{CJK UNIFIED IDEOGRAPH-4EF6}) missing from font(s) DejaVu Sans.
#   plt.savefig("graph.png", dpi=150)
# C:\Users\asami\AppData\Local\Temp\ipykernel_8320\299724962.py:67: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.savefig("graph.png", dpi=150)
# C:\Users\asami\AppData\Local\Temp\ipykernel_8320\299724962.py:67: UserWarning: Glyph 26376 (\N{CJK UNIFIED IDEOGRAPH-6708}) missing from font(s) DejaVu Sans.
#   plt.savefig("graph.png", dpi=150)
# C:\Users\asami\AppData\Local\Temp\ipykernel_8320\299724962.py:67: UserWarning: Glyph 12372 (\N{HIRAGANA LETTER GO}) missing from font(s) DejaVu Sans.
#   plt.savefig("graph.png", dpi=150)
# C:\Users\asami\AppData\Local\Temp\ipykernel_8320\299724962.py:67: UserWarning: Glyph 12392 (\N{HIRAGANA LETTER TO}) missing from font(s) DejaVu Sans.
#   plt.savefig("graph.png", dpi=150)
# C:\Users\asami\AppData\Local\Temp\ipykernel_8320\299724962.py:67: UserWarning: Glyph 12398 (\N{HIRAGANA LETTER NO}) missing from font(s) DejaVu Sans.
#   plt.savefig("graph.png", dpi=150)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 20107 (\N{CJK UNIFIED IDEOGRAPH-4E8B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 25925 (\N{CJK UNIFIED IDEOGRAPH-6545}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 20214 (\N{CJK UNIFIED IDEOGRAPH-4EF6}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 26376 (\N{CJK UNIFIED IDEOGRAPH-6708}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12372 (\N{HIRAGANA LETTER GO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12392 (\N{HIRAGANA LETTER TO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12398 (\N{HIRAGANA LETTER NO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ✔ graph.png として保存しました！

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = load_csv_safely("jitennsyadeta.csv")

df["date"] = pd.to_datetime(df[date_col], errors="coerce")
df = df.dropna(subset=["date"])
df["month"] = df["date"].dt.month
monthly_counts = df["month"].value_counts().sort_index()

# 季節ごとの色
colors = ["#87cefa" if m in [12,1,2] else
          "#98fb98" if m in [3,4,5] else
          "#ffd700" if m in [6,7,8] else
          "#ffa07a"
          for m in monthly_counts.index]

plt.figure(figsize=(12,6))

plt.suptitle("自転車事故データ分析", fontsize=18)
plt.title("月別事故件数（季節別色分け）", fontsize=14)

plt.bar(monthly_counts.index, monthly_counts.values, color=colors)

plt.xticks(range(1, 13),
           ["1月","2月","3月","4月","5月","6月","7月","8月","9月","10月","11月","12月"])

plt.xlabel("月")
plt.ylabel("事故件数")
plt.grid(True, linestyle="--", alpha=0.4)
plt.legend(["冬","春","夏","秋"])

# 注釈
max_month = monthly_counts.idxmax()
max_value = monthly_counts.max()
plt.text(max_month, max_value, "← 最も事故が多い月", fontsize=12, color="red")

plt.show()
# Out:
# Trying encoding: utf-8-sig
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 20107 (\N{CJK UNIFIED IDEOGRAPH-4E8B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 25925 (\N{CJK UNIFIED IDEOGRAPH-6545}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 20214 (\N{CJK UNIFIED IDEOGRAPH-4EF6}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 26376 (\N{CJK UNIFIED IDEOGRAPH-6708}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 21029 (\N{CJK UNIFIED IDEOGRAPH-5225}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 65288 (\N{FULLWIDTH LEFT PARENTHESIS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 23395 (\N{CJK UNIFIED IDEOGRAPH-5B63}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 31680 (\N{CJK UNIFIED IDEOGRAPH-7BC0}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 33394 (\N{CJK UNIFIED IDEOGRAPH-8272}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12369 (\N{HIRAGANA LETTER KE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 26368 (\N{CJK UNIFIED IDEOGRAPH-6700}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12418 (\N{HIRAGANA LETTER MO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12364 (\N{HIRAGANA LETTER GA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 22810 (\N{CJK UNIFIED IDEOGRAPH-591A}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12356 (\N{HIRAGANA LETTER I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 20908 (\N{CJK UNIFIED IDEOGRAPH-51AC}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 33258 (\N{CJK UNIFIED IDEOGRAPH-81EA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 36578 (\N{CJK UNIFIED IDEOGRAPH-8EE2}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 36554 (\N{CJK UNIFIED IDEOGRAPH-8ECA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12487 (\N{KATAKANA LETTER DE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12540 (\N{KATAKANA-HIRAGANA PROLONGED SOUND MARK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12479 (\N{KATAKANA LETTER TA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 26512 (\N{CJK UNIFIED IDEOGRAPH-6790}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# ---------------------------------------------------
# ❶ 文字化けを防ぎながら CSV を読み込む
# ---------------------------------------------------
def load_csv_safely(path):
    encodings = ["utf-8-sig", "shift_jis", "cp932", "euc_jp"]
    for enc in encodings:
        try:
            print(f"Trying encoding: {enc}")
            return pd.read_csv(path, encoding=enc)
        except:
            pass
    raise ValueError("読み込みに失敗しました")

file_path = "jitennsyadeta.csv"
df = load_csv_safely(file_path)

# ---------------------------------------------------
# ❷ 日付に変換（自動で日付列を探す）
# ---------------------------------------------------
date_col = None
for col in df.columns:
    if "日" in col or "月" in col or "年" in col:
        date_col = col
        break

df["date"] = pd.to_datetime(df[date_col], errors="coerce")
df = df.dropna(subset=["date"])

# ---------------------------------------------------
# ❸ 月ごとに集計
# ---------------------------------------------------
df["month"] = df["date"].dt.month
monthly_counts = df["month"].value_counts().sort_index()

# ---------------------------------------------------
# ❹ 日本語ラベル付きグラフ
# ---------------------------------------------------
plt.figure(figsize=(10,5))
plt.bar(monthly_counts.index, monthly_counts.values)

# ★★ 日本語ラベルを追加 ★★
plt.title("月ごとの自転車事故件数", fontsize=16)
plt.xlabel("月（1月〜12月）", fontsize=12)
plt.ylabel("事故件数", fontsize=12)

# x軸を1〜12の整数に
plt.xticks(range(1, 13))

plt.grid(True, linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# Trying encoding: utf-8-sig
# C:\Users\asami\AppData\Local\Temp\ipykernel_8320\3940308551.py:53: UserWarning: Glyph 26376 (\N{CJK UNIFIED IDEOGRAPH-6708}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\asami\AppData\Local\Temp\ipykernel_8320\3940308551.py:53: UserWarning: Glyph 65288 (\N{FULLWIDTH LEFT PARENTHESIS}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\asami\AppData\Local\Temp\ipykernel_8320\3940308551.py:53: UserWarning: Glyph 12316 (\N{WAVE DASH}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\asami\AppData\Local\Temp\ipykernel_8320\3940308551.py:53: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\asami\AppData\Local\Temp\ipykernel_8320\3940308551.py:53: UserWarning: Glyph 20107 (\N{CJK UNIFIED IDEOGRAPH-4E8B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\asami\AppData\Local\Temp\ipykernel_8320\3940308551.py:53: UserWarning: Glyph 25925 (\N{CJK UNIFIED IDEOGRAPH-6545}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\asami\AppData\Local\Temp\ipykernel_8320\3940308551.py:53: UserWarning: Glyph 20214 (\N{CJK UNIFIED IDEOGRAPH-4EF6}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\asami\AppData\Local\Temp\ipykernel_8320\3940308551.py:53: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\asami\AppData\Local\Temp\ipykernel_8320\3940308551.py:53: UserWarning: Glyph 12372 (\N{HIRAGANA LETTER GO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\asami\AppData\Local\Temp\ipykernel_8320\3940308551.py:53: UserWarning: Glyph 12392 (\N{HIRAGANA LETTER TO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\asami\AppData\Local\Temp\ipykernel_8320\3940308551.py:53: UserWarning: Glyph 12398 (\N{HIRAGANA LETTER NO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\asami\AppData\Local\Temp\ipykernel_8320\3940308551.py:53: UserWarning: Glyph 33258 (\N{CJK UNIFIED IDEOGRAPH-81EA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\asami\AppData\Local\Temp\ipykernel_8320\3940308551.py:53: UserWarning: Glyph 36578 (\N{CJK UNIFIED IDEOGRAPH-8EE2}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\asami\AppData\Local\Temp\ipykernel_8320\3940308551.py:53: UserWarning: Glyph 36554 (\N{CJK UNIFIED IDEOGRAPH-8ECA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 20107 (\N{CJK UNIFIED IDEOGRAPH-4E8B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 25925 (\N{CJK UNIFIED IDEOGRAPH-6545}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 20214 (\N{CJK UNIFIED IDEOGRAPH-4EF6}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 26376 (\N{CJK UNIFIED IDEOGRAPH-6708}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12372 (\N{HIRAGANA LETTER GO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12392 (\N{HIRAGANA LETTER TO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12398 (\N{HIRAGANA LETTER NO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 33258 (\N{CJK UNIFIED IDEOGRAPH-81EA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 36578 (\N{CJK UNIFIED IDEOGRAPH-8EE2}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 36554 (\N{CJK UNIFIED IDEOGRAPH-8ECA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 65288 (\N{FULLWIDTH LEFT PARENTHESIS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 12316 (\N{WAVE DASH}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\asami\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# ---------------------------------------------------
# ❶ CSV 読み込み（文字化け対策付き）
# ---------------------------------------------------
def load_csv_safely(path):
    encodings = ["utf-8-sig", "shift_jis", "cp932", "euc_jp"]
    for enc in encodings:
        try:
            return pd.read_csv(path, encoding=enc)
        except:
            continue
    raise ValueError("Encoding error")

file_path = "jitennsyadeta.csv"
df = load_csv_safely(file_path)

# ---------------------------------------------------
# ❷ 日付列を自動検出
# ---------------------------------------------------
date_col = None
for col in df.columns:
    if any(x in col for x in ["年", "月", "日"]):
        date_col = col
        break

df["date"] = pd.to_datetime(df[date_col], errors="coerce")
df = df.dropna(subset=["date"])

# ---------------------------------------------------
# ❸ 月ごとの件数
# ---------------------------------------------------
df["month"] = df["date"].dt.month
monthly_counts = df["month"].value_counts().sort_index()

# ---------------------------------------------------
# ❹ 月名（ローマ字）マップ
# ---------------------------------------------------
romaji_months = {
    1: "Ichigatsu",
    2: "Nigatsu",
    3: "Sangatsu",
    4: "Shigatsu",
    5: "Gogatsu",
    6: "Rokugatsu",
    7: "Shichigatsu",
    8: "Hachigatsu",
    9: "Kugatsu",
    10: "Juugatsu",
    11: "Juuichigatsu",
    12: "Juunigatsu"
}

labels = [romaji_months[m] for m in monthly_counts.index]

# ---------------------------------------------------
# ❺ グラフ描画（GitHub Pages 対応：ローマ字）
# ---------------------------------------------------
plt.figure(figsize=(12,6))
plt.bar(labels, monthly_counts.values)

plt.xticks(rotation=45, ha="right")
plt.xlabel("Gatsu (Month)")
plt.ylabel("Jiko Kensuu (Count of Accidents)")
plt.title("Kisetsu / Gatsu betsu no Jiko Kensuu (Season / Month Accident Count)")
plt.grid(True, linestyle="--", alpha=0.5)

plt.tight_layout()
plt.show()

# %%
plt.savefig("monthly_accidents.png", dpi=300)

# %%
Add monthly accidents graph
# Out:
#   Cell In[23], line 1
#     Add monthly accidents graph
#         ^
# SyntaxError: invalid syntax

# %%
Git: Push
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 Git: Push
#
# NameError: name 'Push' is not defined

# %%
# 月ごとの事故件数グラフ

![monthly graph](monthly_accidents.png)
# Out:
# '[monthly' �́A�����R�}���h�܂��͊O���R�}���h�A
# ����\�ȃv���O�����܂��̓o�b�` �t�@�C���Ƃ��ĔF������Ă��܂���B

# %%
import matplotlib.pyplot as plt

# 例のデータ（あなたのデータに置き換えてOK）
months = ["Jan", "Feb", "Mar", "Apr", "May"]
counts = [10, 12, 8, 15, 11]

plt.figure(figsize=(8,5))
plt.plot(months, counts, marker="o")
plt.title("Monthly Accident Count")
plt.xlabel("Month")
plt.ylabel("Accident Count")

# ここで VS Code 内のフォルダに保存される
plt.savefig("graph.png", dpi=300, bbox_inches="tight")

plt.close()
print("graph.png saved!")
# Out:
# graph.png saved!
